# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

from sklearn.preprocessing import LabelEncoder
from dateutil.relativedelta import relativedelta
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import cut_tree
from sklearn.metrics import silhouette_score
from scipy.cluster.hierarchy import single, cophenet
from scipy.spatial.distance import pdist

import pickle
import warnings; warnings.simplefilter('ignore')

# %% [markdown]
# # 1. Load dataset

# %%
df = pd.read_excel('Online Retail.xlsx')

# %%
df.sample(10)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 471980    576658     22947           WOODEN ADVENT CALENDAR RED         4
# 339285    566585    72351A   SET/6 TURQUOISE BUTTERFLY T-LIGHTS        12
# 455519    575627     22314          OFFICE MUG WARMER CHOC+BLUE         6
# 497229    578353     22294           HEART FILIGREE DOVE  SMALL        24
# 92660     544202     84987      SET OF 36 TEATIME PAPER DOILIES         1
# 536132    581219     22701                        PINK DOG BOWL         2
# 514289    579692     23571        TRADITIONAL NAUGHTS & CROSSES        12
# 526169    580652    84032B  CHARLIE + LOLA RED HOT WATER BOTTLE       144
# 187757    553005     22918                  HERB MARKER PARSLEY         2
# 466843    576329     23002            TRAVEL CARD WALLET SKULLS         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 471980 2011-11-16 11:05:00       7.95     14534.0  United Kingdom
# 339285 2011-09-13 14:06:00       2.10     16409.0  United Kingdom
# 455519 2011-11-10 13:28:00       2.95     17977.0  United Kingdom
# 497229 2011-11-24 10:07:00       1.25     14825.0  United Kingdom
# 92660  2011-02-17 10:29:00       3.75         NaN  United Kingdom
# 536132 2011-12-08 09:28:00       2.46         NaN  United Kingdom
# 514289 2011-11-30 14:05:00       1.65     12433.0          Norway
# 526169 2011-12-05 13:33:00       0.79     17511.0  United Kingdom
# 187757 2011-05-12 16:29:00       0.65     14651.0  United Kingdom
# 466843 2011-11-14 15:22:00       0.83         NaN  United Kingdom

# %% [markdown]
# # 2. Exploring and Cleaning the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
# df = df[df['CustomerID'].notna()]
# df.isnull().any()

# %%
# df['CustomerID'] = df['CustomerID'].astype("int")
# df

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %% [markdown]
# #### Check if there are any missing value

# %%
df.isnull().any()
# Out:
# InvoiceNo      False
# StockCode      False
# Description     True
# Quantity       False
# InvoiceDate    False
# UnitPrice      False
# CustomerID      True
# Country        False
# dtype: bool

# %%
plt.figure(figsize = (5, 5)) 
df.isnull().mean(axis=0).plot.barh()
plt.title("Ration of missing value")
# Out:
# Text(0.5, 1.0, 'Ration of missing value')

# %% [markdown]
# ##### The missing values are only in the CustomerID column and the description column

# %% [markdown]
# #### Check if any column have a single value

# %%
print(df.nunique())
# Out:
# InvoiceNo      25900
# StockCode       4070
# Description     4223
# Quantity         722
# InvoiceDate    23260
# UnitPrice       1630
# CustomerID      4372
# Country           38
# dtype: int64

# %% [markdown]
# ##### There are no single value in datasets

# %% [markdown]
# #### Check if there are any dubplicat value

# %%
duplicateRowsDF = df[df.duplicated()]

# %%
print("Duplicate Rows based on all columns are :")
print(duplicateRowsDF)
# Out:
# Duplicate Rows based on all columns are :
#        InvoiceNo StockCode                        Description  Quantity  \
# 517       536409     21866        UNION JACK FLAG LUGGAGE TAG         1
# 527       536409     22866      HAND WARMER SCOTTY DOG DESIGN         1
# 537       536409     22900    SET 2 TEA TOWELS I LOVE LONDON          1
# 539       536409     22111       SCOTTIE DOG HOT WATER BOTTLE         1
# 555       536412     22327  ROUND SNACK BOXES SET OF 4 SKULLS         1
# ...          ...       ...                                ...       ...
# 541675    581538     22068        BLACK PIRATE TREASURE CHEST         1
# 541689    581538     23318     BOX OF 6 MINI VINTAGE CRACKERS         1
# 541692    581538     22992             REVOLVER WOODEN RULER          1
# 541699    581538     22694                       WICKER STAR          1
# 541701    581538     23343       JUMBO BAG VINTAGE CHRISTMAS          1
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 517    2010-12-01 11:45:00       1.25     17908.0  United Kingdom
# 527    2010-12-01 11:45:00       2.10     17908.0  United Kingdom
# 537    2010-12-01 11:45:00       2.95     17908.0  United Kingdom
# 539    2010-12-01 11:45:00       4.95     17908.0  United Kingdom
# 555    2010-12-01 11:49:00       2.95     17920.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541675 2011-12-09 11:34:00       0.39     14446.0  United Kingdom
# 541689 2011-12-09 11:34:00       2.49     14446.0  United Kingdom
# 541692 2011-12-09 11:34:00       1.95     14446.0  United Kingdom
# 541699 2011-12-09 11:34:00       2.10     14446.0  United Kingdom
# 541701 2011-12-09 11:34:00       2.08     14446.0  United Kingdom
#
# [5268 rows x 8 columns]

# %% [markdown]
# ##### There are 5268 duplicated rows

# %%
df.drop_duplicates(inplace = True)

# %%
print(df[df.duplicated()])
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %% [markdown]
# #### check null value of Description

# %%
null_data = df[df['Description'].isnull()]
null_data
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 622       536414     22139         NaN        56 2010-12-01 11:52:00
# 1970      536545     21134         NaN         1 2010-12-01 14:32:00
# 1971      536546     22145         NaN         1 2010-12-01 14:33:00
# 1972      536547     37509         NaN         1 2010-12-01 14:33:00
# 1987      536549    85226A         NaN         1 2010-12-01 14:34:00
# ...          ...       ...         ...       ...                 ...
# 535322    581199     84581         NaN        -2 2011-12-07 18:26:00
# 535326    581203     23406         NaN        15 2011-12-07 18:31:00
# 535332    581209     21620         NaN         6 2011-12-07 18:35:00
# 536981    581234     72817         NaN        27 2011-12-08 10:33:00
# 538554    581408     85175         NaN        20 2011-12-08 14:06:00
#
#         UnitPrice  CustomerID         Country
# 622           0.0         NaN  United Kingdom
# 1970          0.0         NaN  United Kingdom
# 1971          0.0         NaN  United Kingdom
# 1972          0.0         NaN  United Kingdom
# 1987          0.0         NaN  United Kingdom
# ...           ...         ...             ...
# 535322        0.0         NaN  United Kingdom
# 535326        0.0         NaN  United Kingdom
# 535332        0.0         NaN  United Kingdom
# 536981        0.0         NaN  United Kingdom
# 538554        0.0         NaN  United Kingdom
#
# [1454 rows x 8 columns]

# %% [markdown]
# #### check cancelled orders

# %%
x = df['InvoiceNo'].str.contains('C')
x.fillna(0, inplace=True)

# %%
x = x.astype(int)

# %%
x.value_counts()
# Out:
# 0    527390
# 1      9251
# Name: InvoiceNo, dtype: int64

# %%
df['order_canceled'] = x
df.sample(10)
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 211161    555348     22191             IVORY DINER WALL CLOCK         2
# 409673    572068     23177           TREASURE ISLAND BOOK BOX         8
# 225880    556740     22998       TRAVEL CARD WALLET KEEP CALM        20
# 430230    573584     22892  SET OF SALT AND PEPPER TOADSTOOLS        24
# 354451    567879     22144     CHRISTMAS CRAFT LITTLE FRIENDS         6
# 312009    564335     22921                HERB MARKER CHIVES          2
# 139535    548327     22982                PANTRY PASTRY BRUSH         3
# 173282    551686     23154           SET OF 4 JAM JAR MAGNETS        12
# 155824    550016     22607        WOODEN ROUNDERS GARDEN SET          6
# 480414    577300    85034C        3 ROSE MORRIS BOXED CANDLES        12
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# 211161 2011-06-02 12:06:00       8.50     15184.0  United Kingdom
# 409673 2011-10-20 13:20:00       2.25     13159.0  United Kingdom
# 225880 2011-06-14 12:06:00       0.42     17346.0  United Kingdom
# 430230 2011-10-31 14:36:00       1.25     16705.0  United Kingdom
# 354451 2011-09-22 14:53:00       2.10     16161.0  United Kingdom
# 312009 2011-08-24 14:23:00       0.65     15800.0  United Kingdom
# 139535 2011-03-30 13:05:00       1.25     16788.0  United Kingdom
# 173282 2011-05-03 12:53:00       2.08     13668.0  United Kingdom
# 155824 2011-04-14 10:54:00       9.95     15416.0  United Kingdom
# 480414 2011-11-18 12:53:00       1.25     16924.0  United Kingdom
#
#         order_canceled
# 211161               0
# 409673               0
# 225880               0
# 430230               0
# 354451               0
# 312009               0
# 139535               0
# 173282               0
# 155824               0
# 480414               0

# %%
df['order_canceled'].value_counts()
# Out:
# 0    527390
# 1      9251
# Name: order_canceled, dtype: int64

# %%
n1 = df['order_canceled'].value_counts()[1]
n2 = len(df.index)
print('Number of orders canceled: {}/{} ({:.2f}%) '.format(n1, n2, n1/n2*100))
# Out:
# Number of orders canceled: 9251/536641 (1.72%)

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
#         order_canceled
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 541904               0
# 541905               0
# 541906               0
# 541907               0
# 541908               0
#
# [536641 rows x 9 columns]

# %%
df[df['order_canceled']==1]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# 141    2010-12-01 09:41:00      27.50     14527.0  United Kingdom
# 154    2010-12-01 09:49:00       4.65     15311.0  United Kingdom
# 235    2010-12-01 10:24:00       1.65     17548.0  United Kingdom
# 236    2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# 237    2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# ...                    ...        ...         ...             ...
# 540449 2011-12-09 09:57:00       0.83     14397.0  United Kingdom
# 541541 2011-12-09 10:28:00     224.69     15498.0  United Kingdom
# 541715 2011-12-09 11:57:00      10.95     15311.0  United Kingdom
# 541716 2011-12-09 11:58:00       1.25     17315.0  United Kingdom
# 541717 2011-12-09 11:58:00       1.25     17315.0  United Kingdom
#
#         order_canceled
# 141                  1
# 154                  1
# 235                  1
# 236                  1
# 237                  1
# ...                ...
# 540449               1
# 541541               1
# 541715               1
# 541716               1
# 541717               1
#
# [9251 rows x 9 columns]

# %% [markdown]
# #### Drop Value which CustomerID have null

# %%
df = df[df['CustomerID'].notna()]
df['CustomerID'] = df['CustomerID'].astype("int")

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# 0      2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1      2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2      2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3      2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4      2010-12-01 08:26:00       3.39       17850  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85       12680          France
# 541905 2011-12-09 12:50:00       2.10       12680          France
# 541906 2011-12-09 12:50:00       4.15       12680          France
# 541907 2011-12-09 12:50:00       4.15       12680          France
# 541908 2011-12-09 12:50:00       4.95       12680          France
#
#         order_canceled
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 541904               0
# 541905               0
# 541906               0
# 541907               0
# 541908               0
#
# [401604 rows x 9 columns]

# %%
df.reset_index(drop=True,inplace=True)

# %% [markdown]
# #### Checking if it has negative quantities.

# %%
len(df.loc[df['Quantity'] < 0,:])
# Out:
# 8872

# %%
df.loc[df['Quantity'] < 0,:]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 401159   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 401243   C581499         M                            Manual        -1
# 401410   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 401411   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 401412   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# 141    2010-12-01 09:41:00      27.50       14527  United Kingdom
# 154    2010-12-01 09:49:00       4.65       15311  United Kingdom
# 235    2010-12-01 10:24:00       1.65       17548  United Kingdom
# 236    2010-12-01 10:24:00       0.29       17548  United Kingdom
# 237    2010-12-01 10:24:00       0.29       17548  United Kingdom
# ...                    ...        ...         ...             ...
# 401159 2011-12-09 09:57:00       0.83       14397  United Kingdom
# 401243 2011-12-09 10:28:00     224.69       15498  United Kingdom
# 401410 2011-12-09 11:57:00      10.95       15311  United Kingdom
# 401411 2011-12-09 11:58:00       1.25       17315  United Kingdom
# 401412 2011-12-09 11:58:00       1.25       17315  United Kingdom
#
#         order_canceled
# 141                  1
# 154                  1
# 235                  1
# 236                  1
# 237                  1
# ...                ...
# 401159               1
# 401243               1
# 401410               1
# 401411               1
# 401412               1
#
# [8872 rows x 9 columns]

# %%
df.isnull().any()
# Out:
# InvoiceNo         False
# StockCode         False
# Description       False
# Quantity          False
# InvoiceDate       False
# UnitPrice         False
# CustomerID        False
# Country           False
# order_canceled    False
# dtype: bool

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401604 entries, 0 to 401603
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   InvoiceNo       401604 non-null  object
#  1   StockCode       401604 non-null  object
#  2   Description     401604 non-null  object
#  3   Quantity        401604 non-null  int64
#  4   InvoiceDate     401604 non-null  datetime64[ns]
#  5   UnitPrice       401604 non-null  float64
#  6   CustomerID      401604 non-null  int32
#  7   Country         401604 non-null  object
#  8   order_canceled  401604 non-null  int32
# dtypes: datetime64[ns](1), float64(1), int32(2), int64(1), object(4)
# memory usage: 24.5+ MB

# %% [markdown]
# # 3. Exploratory Data

# %% [markdown]
# ## 3.1 Countries

# %%
df.Country.nunique()
# Out:
# 37

# %%
customer_country=df[['Country','CustomerID']].drop_duplicates()
customer_country.groupby(['Country'])['CustomerID'].aggregate('count').reset_index().sort_values('CustomerID', ascending=False)
# Out:
#                  Country  CustomerID
# 35        United Kingdom        3950
# 14               Germany          95
# 13                France          87
# 30                 Spain          31
# 3                Belgium          25
# 32           Switzerland          21
# 26              Portugal          19
# 18                 Italy          15
# 12               Finland          12
# 1                Austria          11
# 24                Norway          10
# 23           Netherlands           9
# 0              Australia           9
# 9                Denmark           9
# 6        Channel Islands           9
# 7                 Cyprus           8
# 31                Sweden           8
# 19                 Japan           8
# 25                Poland           6
# 33                   USA           4
# 5                 Canada           4
# 36           Unspecified           4
# 17                Israel           4
# 15                Greece           4
# 10                  EIRE           3
# 22                 Malta           2
# 34  United Arab Emirates           2
# 2                Bahrain           2
# 8         Czech Republic           1
# 21             Lithuania           1
# 20               Lebanon           1
# 27                   RSA           1
# 28          Saudi Arabia           1
# 29             Singapore           1
# 16               Iceland           1
# 4                 Brazil           1
# 11    European Community           1

# %%
n1 = df[df['Country'] == 'United Kingdom'].value_counts('Country').sum()
n2 = len(df['Country'])
n1
print('Number of customers from UK: {}/{} ({:.2f}%) '.format(n1, n2, n1/n2*100))
# Out:
# Number of customers from UK: 356728/401604 (88.83%)

# %%
temp = df.groupby(['Country'],as_index=False).agg({'InvoiceNo':'nunique'}).rename(columns = {'InvoiceNo':'Orders'})
total = temp['Orders'].sum(axis=0)
temp['%Orders'] = round((temp['Orders']/total)*100,4)

# %%
temp.sort_values(by=['%Orders'],ascending=False,inplace=True)
temp.reset_index(drop=True,inplace=True)

# %%
plt.figure(figsize=(15,10))
splot=sns.barplot(x="Country",y="%Orders",data=temp[:10])
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')
plt.xlabel("Country", size=14)
plt.ylabel("%Orders", size=14)
# Out:
# Text(0, 0.5, '%Orders')

# %% [markdown]
# ##### Almost 90% of the data is coming from UK !

# %% [markdown]
# ## 3.2 Quantity

# %%
df['Quantity'].describe()
# Out:
# count    401604.000000
# mean         12.183273
# std         250.283037
# min      -80995.000000
# 25%           2.000000
# 50%           5.000000
# 75%          12.000000
# max       80995.000000
# Name: Quantity, dtype: float64

# %%
df[(df['Quantity']<0)].head(5)
# Out:
#     InvoiceNo StockCode                       Description  Quantity  \
# 141   C536379         D                          Discount        -1
# 154   C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235   C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236   C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237   C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
#
#             InvoiceDate  UnitPrice  CustomerID         Country  order_canceled
# 141 2010-12-01 09:41:00      27.50       14527  United Kingdom               1
# 154 2010-12-01 09:49:00       4.65       15311  United Kingdom               1
# 235 2010-12-01 10:24:00       1.65       17548  United Kingdom               1
# 236 2010-12-01 10:24:00       0.29       17548  United Kingdom               1
# 237 2010-12-01 10:24:00       0.29       17548  United Kingdom               1

# %% [markdown]
# #### The Quantity is seem good to go

# %% [markdown]
# ## 3.3 Stock Code

# %%
df['StockCode'].sample(20)
# Out:
# 187138     22937
# 161356    51014A
# 284624     84347
# 139114     21770
# 307392     21528
# 39609      21479
# 29156      22361
# 322672     23570
# 244783     23425
# 211027     22485
# 378589     22028
# 207353     22470
# 4592       22632
# 369218     23501
# 5709       22951
# 333134     21485
# 180193    84536B
# 279786     22624
# 192898     22461
# 60258      23232
# Name: StockCode, dtype: object

# %%
len(df['StockCode'].unique())
# Out:
# 3684

# %% [markdown]
# ### found some special code

# %%
list_special_codes = df[df['StockCode'].str.contains('^[a-zA-Z]+', na=False)]['StockCode'].unique()
list_special_codes
# Out:
# array(['POST', 'D', 'C2', 'M', 'BANK CHARGES', 'PADS', 'DOT', 'CRUK'],
#       dtype=object)

# %%
df[df['StockCode'] == 'POST']
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 45        536370      POST     POSTAGE         3 2010-12-01 08:45:00
# 386       536403      POST     POSTAGE         1 2010-12-01 11:27:00
# 1097      536527      POST     POSTAGE         1 2010-12-01 13:04:00
# 3789      536840      POST     POSTAGE         1 2010-12-02 18:27:00
# 3968      536852      POST     POSTAGE         1 2010-12-03 09:51:00
# ...          ...       ...         ...       ...                 ...
# 401177    581493      POST     POSTAGE         1 2011-12-09 10:10:00
# 401195    581494      POST     POSTAGE         2 2011-12-09 10:13:00
# 401425    581570      POST     POSTAGE         1 2011-12-09 11:59:00
# 401462    581574      POST     POSTAGE         2 2011-12-09 12:09:00
# 401463    581578      POST     POSTAGE         3 2011-12-09 12:16:00
#
#         UnitPrice  CustomerID      Country  order_canceled
# 45           18.0       12583       France               0
# 386          15.0       12791  Netherlands               0
# 1097         18.0       12662      Germany               0
# 3789         18.0       12738      Germany               0
# 3968         18.0       12686       France               0
# ...           ...         ...          ...             ...
# 401177       15.0       12423      Belgium               0
# 401195       18.0       12518      Germany               0
# 401425       18.0       12662      Germany               0
# 401462       18.0       12526      Germany               0
# 401463       18.0       12713      Germany               0
#
# [1196 rows x 9 columns]

# %%
df[df['StockCode'] == 'BANK CHARGES']
# Out:
#        InvoiceNo     StockCode   Description  Quantity         InvoiceDate  \
# 3158      536779  BANK CHARGES  Bank Charges         1 2010-12-02 15:08:00
# 37886     541505  BANK CHARGES  Bank Charges         1 2011-01-18 15:58:00
# 104648    549717  BANK CHARGES  Bank Charges         1 2011-04-11 14:56:00
# 121491    551945  BANK CHARGES  Bank Charges         1 2011-05-05 11:09:00
# 235306    565735  BANK CHARGES  Bank Charges         1 2011-09-06 12:25:00
# 262731    568375  BANK CHARGES  Bank Charges         1 2011-09-26 17:01:00
# 262732    568375  BANK CHARGES  Bank Charges         1 2011-09-26 17:01:00
# 300216    571900  BANK CHARGES  Bank Charges         1 2011-10-19 14:26:00
# 319837    573586  BANK CHARGES  Bank Charges         1 2011-10-31 14:48:00
# 327551    574546  BANK CHARGES  Bank Charges         1 2011-11-04 14:59:00
# 377701    579137  BANK CHARGES  Bank Charges         1 2011-11-28 12:51:00
# 397147    581127  BANK CHARGES  Bank Charges         1 2011-12-07 12:45:00
#
#         UnitPrice  CustomerID         Country  order_canceled
# 3158       15.000       15823  United Kingdom               0
# 37886      15.000       15939  United Kingdom               0
# 104648     15.000       14606  United Kingdom               0
# 121491     15.000       16714  United Kingdom               0
# 235306     15.000       16904  United Kingdom               0
# 262731     15.000       13405  United Kingdom               0
# 262732      0.001       13405  United Kingdom               0
# 300216     15.000       13263  United Kingdom               0
# 319837     15.000       14704  United Kingdom               0
# 327551     15.000       13651  United Kingdom               0
# 377701     15.000       14704  United Kingdom               0
# 397147     15.000       16271  United Kingdom               0

# %% [markdown]
# ## 3.4 InvoiceNo - Cancelation Code

# %%
# Constucting a basket for later use
temp = df.groupby(by=['CustomerID', 'InvoiceNo'], as_index=False)['InvoiceDate'].count()
nb_products_per_basket = temp.rename(columns = {'InvoiceDate':'Number of products'})

# %%
nb_products_per_basket.InvoiceNo = nb_products_per_basket.InvoiceNo.astype(str)
nb_products_per_basket['order_canceled'] = nb_products_per_basket['InvoiceNo'].apply(lambda x:int('C' in x))
len(nb_products_per_basket[nb_products_per_basket['order_canceled']==1])/len(nb_products_per_basket)*100
# Out:
# 16.466876971608833

# %% [markdown]
# ##### After drop some datas it still appears that more than 16% of the transactions were canceled. Let's take a look at some rows where the transaction was canceled.

# %%
nb_products_per_basket[nb_products_per_basket['order_canceled']==1][:5]
# Out:
#     CustomerID InvoiceNo  Number of products  order_canceled
# 1        12346   C541433                   1               1
# 23       12352   C545329                   2               1
# 24       12352   C545330                   1               1
# 25       12352   C547388                   7               1
# 39       12359   C549955                   2               1

# %%
df[df['CustomerID'] == 12346]
# Out:
#       InvoiceNo StockCode                     Description  Quantity  \
# 37511    541431     23166  MEDIUM CERAMIC TOP STORAGE JAR     74215
# 37516   C541433     23166  MEDIUM CERAMIC TOP STORAGE JAR    -74215
#
#               InvoiceDate  UnitPrice  CustomerID         Country  \
# 37511 2011-01-18 10:01:00       1.04       12346  United Kingdom
# 37516 2011-01-18 10:17:00       1.04       12346  United Kingdom
#
#        order_canceled
# 37511               0
# 37516               1

# %% [markdown]
# ##### Look like it's a duplicate of the canceled transaction in the data. Let's see if this is always the case.

# %%
test = df[df['Quantity'] < 0][['CustomerID','Quantity',
                                                   'StockCode','Description','UnitPrice']]
for index, col in  test.iterrows():
    if df[(df['CustomerID'] == col[0]) & (df['Quantity'] == -col[1]) 
                & (df['Description'] == col[3])].shape[0] == 0: 
        print(test.loc[index])
        print('It is not always the case')
        break
# Out:
# CustomerID        14527
# Quantity             -1
# StockCode             D
# Description    Discount
# UnitPrice          27.5
# Name: 141, dtype: object
# It is not always the case

# %%
df[df['CustomerID'] == 14527].head(5)
# Out:
#      InvoiceNo StockCode                        Description  Quantity  \
# 141    C536379         D                           Discount        -1
# 6521    537159     22112         CHOCOLATE HOT WATER BOTTLE         6
# 6522    537159     22111       SCOTTIE DOG HOT WATER BOTTLE         1
# 6523    537159     21479      WHITE SKULL HOT WATER BOTTLE          1
# 6524    537159     22114  HOT WATER BOTTLE TEA AND SYMPATHY         6
#
#              InvoiceDate  UnitPrice  CustomerID         Country  \
# 141  2010-12-01 09:41:00      27.50       14527  United Kingdom
# 6521 2010-12-05 13:17:00       4.95       14527  United Kingdom
# 6522 2010-12-05 13:17:00       4.95       14527  United Kingdom
# 6523 2010-12-05 13:17:00       3.75       14527  United Kingdom
# 6524 2010-12-05 13:17:00       3.95       14527  United Kingdom
#
#       order_canceled
# 141                1
# 6521               0
# 6522               0
# 6523               0
# 6524               0

# %% [markdown]
# ##### It appears that when there is a discount there are no duplicate. Let's try without the discount values

# %%
data_check = df[(df['Quantity'] < 0) & (df['Description'] != 'Discount')][
                                 ['CustomerID','Quantity','StockCode',
                                  'Description','UnitPrice']]

for index, col in  data_check.iterrows():
    if df[(df['CustomerID'] == col[0]) & (df['Quantity'] == -col[1]) 
                & (df['Description'] == col[3])].shape[0] == 0: 
        print('Index :', index)
        print(data_check.loc[index])
        print('The second test is also not the case')
        break
# Out:
# Index : 154
# CustomerID                               15311
# Quantity                                    -1
# StockCode                               35004C
# Description    SET OF 3 COLOURED  FLYING DUCKS
# UnitPrice                                 4.65
# Name: 154, dtype: object
# The second test is also not the case

# %%
df[(df['CustomerID'] == 15311) & (df['Description'] == 'SET OF 3 COLOURED  FLYING DUCKS')]
# Out:
#       InvoiceNo StockCode                      Description  Quantity  \
# 154     C536383    35004C  SET OF 3 COLOURED  FLYING DUCKS        -1
# 6750     537195    35004C  SET OF 3 COLOURED  FLYING DUCKS        12
# 11855   C537805    35004C  SET OF 3 COLOURED  FLYING DUCKS        -1
# 18214    538651    35004C  SET OF 3 COLOURED  FLYING DUCKS        12
# 25143   C539640    35004C  SET OF 3 COLOURED  FLYING DUCKS        -3
# 27303    540157    35004C  SET OF 3 COLOURED  FLYING DUCKS        12
# 37034    541293    35004C  SET OF 3 COLOURED  FLYING DUCKS        12
# 48630   C542866    35004C  SET OF 3 COLOURED  FLYING DUCKS        -2
#
#               InvoiceDate  UnitPrice  CustomerID         Country  \
# 154   2010-12-01 09:49:00       4.65       15311  United Kingdom
# 6750  2010-12-05 13:55:00       4.65       15311  United Kingdom
# 11855 2010-12-08 13:18:00       4.65       15311  United Kingdom
# 18214 2010-12-13 15:07:00       4.65       15311  United Kingdom
# 25143 2010-12-20 15:27:00       4.65       15311  United Kingdom
# 27303 2011-01-05 11:41:00       4.65       15311  United Kingdom
# 37034 2011-01-17 13:39:00       4.65       15311  United Kingdom
# 48630 2011-02-01 12:14:00       4.65       15311  United Kingdom
#
#        order_canceled
# 154                 1
# 6750                0
# 11855               1
# 18214               0
# 25143               1
# 27303               0
# 37034               0
# 48630               1

# %% [markdown]
# ##### So cancel order is just a part of the transaction

# %% [markdown]
# ## 3.5. UnitPrice

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID  order_canceled
# count  401604.000000  401604.000000  401604.000000   401604.000000
# mean       12.183273       3.474064   15281.160818        0.022091
# std       250.283037      69.764035    1714.006089        0.146981
# min    -80995.000000       0.000000   12346.000000        0.000000
# 25%         2.000000       1.250000   13939.000000        0.000000
# 50%         5.000000       1.950000   15145.000000        0.000000
# 75%        12.000000       3.750000   16784.000000        0.000000
# max     80995.000000   38970.000000   18287.000000        1.000000

# %% [markdown]
# ##### The minimum value for the unitprice is 0.

# %%
df[(df['UnitPrice'] == 0)].head(5)
# Out:
#       InvoiceNo StockCode                   Description  Quantity  \
# 6842     537197     22841  ROUND CAKE TIN VINTAGE GREEN         1
# 22619    539263     22580  ADVENT CALENDAR GINGHAM SACK         4
# 25551    539722     22423      REGENCY CAKESTAND 3 TIER        10
# 29374    540372     22090       PAPER BUNTING RETROSPOT        24
# 29376    540372     22553        PLASTERS IN TIN SKULLS        24
#
#               InvoiceDate  UnitPrice  CustomerID         Country  \
# 6842  2010-12-05 14:02:00        0.0       12647         Germany
# 22619 2010-12-16 14:36:00        0.0       16560  United Kingdom
# 25551 2010-12-21 13:45:00        0.0       14911            EIRE
# 29374 2011-01-06 16:41:00        0.0       13081  United Kingdom
# 29376 2011-01-06 16:41:00        0.0       13081  United Kingdom
#
#        order_canceled
# 6842                0
# 22619               0
# 25551               0
# 29374               0
# 29376               0

# %% [markdown]
# ##### it might be a special discount or something else so I'll leave it like that.

# %% [markdown]
# # 4.Feature engineering

# %%
def unique_counts(df):
   for i in df.columns:
       count = df[i].nunique()
       print(i, ": ", count)
unique_counts(df)
# Out:
# InvoiceNo :  22190
# StockCode :  3684
# Description :  3896
# Quantity :  436
# InvoiceDate :  20460
# UnitPrice :  620
# CustomerID :  4372
# Country :  37
# order_canceled :  2

# %% [markdown]
# ## 4.1 Total price

# %%
# Total price feature
df['TotalPrice'] = df['UnitPrice'] * df['Quantity']

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 401599    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 401600    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 401601    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 401602    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 401603    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# 0      2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1      2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2      2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3      2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4      2010-12-01 08:26:00       3.39       17850  United Kingdom
# ...                    ...        ...         ...             ...
# 401599 2011-12-09 12:50:00       0.85       12680          France
# 401600 2011-12-09 12:50:00       2.10       12680          France
# 401601 2011-12-09 12:50:00       4.15       12680          France
# 401602 2011-12-09 12:50:00       4.15       12680          France
# 401603 2011-12-09 12:50:00       4.95       12680          France
#
#         order_canceled  TotalPrice
# 0                    0       15.30
# 1                    0       20.34
# 2                    0       22.00
# 3                    0       20.34
# 4                    0       20.34
# ...                ...         ...
# 401599               0       10.20
# 401600               0       12.60
# 401601               0       16.60
# 401602               0       16.60
# 401603               0       14.85
#
# [401604 rows x 10 columns]

# %%
# Total price feature

# %%
df.insert(loc=2, column='year_month', value=df['InvoiceDate'].map(lambda x: 100*x.year + x.month))
df.insert(loc=3, column='Month', value=df.InvoiceDate.dt.month)
# +1 to make Monday=1.....until Sunday=7
df.insert(loc=4, column='Day', value=(df.InvoiceDate.dt.dayofweek)+1)
df.insert(loc=5, column='Hour', value=df.InvoiceDate.dt.hour)

# %%
df
# Out:
#        InvoiceNo StockCode  year_month  Month  Day  Hour  \
# 0         536365    85123A      201012     12    3     8
# 1         536365     71053      201012     12    3     8
# 2         536365    84406B      201012     12    3     8
# 3         536365    84029G      201012     12    3     8
# 4         536365    84029E      201012     12    3     8
# ...          ...       ...         ...    ...  ...   ...
# 401599    581587     22613      201112     12    5    12
# 401600    581587     22899      201112     12    5    12
# 401601    581587     23254      201112     12    5    12
# 401602    581587     23255      201112     12    5    12
# 401603    581587     22138      201112     12    5    12
#
#                                 Description  Quantity         InvoiceDate  \
# 0        WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1                       WHITE METAL LANTERN         6 2010-12-01 08:26:00
# 2            CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00
# 3       KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01 08:26:00
# 4            RED WOOLLY HOTTIE WHITE HEART.         6 2010-12-01 08:26:00
# ...                                     ...       ...                 ...
# 401599          PACK OF 20 SPACEBOY NAPKINS        12 2011-12-09 12:50:00
# 401600         CHILDREN'S APRON DOLLY GIRL          6 2011-12-09 12:50:00
# 401601        CHILDRENS CUTLERY DOLLY GIRL          4 2011-12-09 12:50:00
# 401602      CHILDRENS CUTLERY CIRCUS PARADE         4 2011-12-09 12:50:00
# 401603        BAKING SET 9 PIECE RETROSPOT          3 2011-12-09 12:50:00
#
#         UnitPrice  CustomerID         Country  order_canceled  TotalPrice
# 0            2.55       17850  United Kingdom               0       15.30
# 1            3.39       17850  United Kingdom               0       20.34
# 2            2.75       17850  United Kingdom               0       22.00
# 3            3.39       17850  United Kingdom               0       20.34
# 4            3.39       17850  United Kingdom               0       20.34
# ...           ...         ...             ...             ...         ...
# 401599       0.85       12680          France               0       10.20
# 401600       2.10       12680          France               0       12.60
# 401601       4.15       12680          France               0       16.60
# 401602       4.15       12680          France               0       16.60
# 401603       4.95       12680          France               0       14.85
#
# [401604 rows x 14 columns]

# %%
revenue_per_countries = df.groupby(["Country"])["TotalPrice"].sum().sort_values()
revenue_per_countries.plot(kind='barh', figsize=(18,12))
plt.title("Revenue per Country")
# Out:
# Text(0.5, 1.0, 'Revenue per Country')

# %%
No_invoice_per_country = df.groupby(["Country"])["InvoiceNo"].count().sort_values()
No_invoice_per_country.plot(kind='barh', figsize=(15,12))
plt.title("Number of Invoices per Country")
# Out:
# Text(0.5, 1.0, 'Number of Invoices per Country')

# %% [markdown]
# ## 4.2 Country

# %%
# le = LabelEncoder()
# le.fit(df['Country'])

# %%
# l = [i for i in range(37)]
# dict(zip(list(le.classes_), l))

# %%
# df['Country'] = le.transform(df['Country'])

# %%
# with open('labelencoder.pickle', 'wb') as g:
#     pickle.dump(le, g)

# %%
df.head(10)
# Out:
#   InvoiceNo StockCode  year_month  Month  Day  Hour  \
# 0    536365    85123A      201012     12    3     8
# 1    536365     71053      201012     12    3     8
# 2    536365    84406B      201012     12    3     8
# 3    536365    84029G      201012     12    3     8
# 4    536365    84029E      201012     12    3     8
# 5    536365     22752      201012     12    3     8
# 6    536365     21730      201012     12    3     8
# 7    536366     22633      201012     12    3     8
# 8    536366     22632      201012     12    3     8
# 9    536367     84879      201012     12    3     8
#
#                            Description  Quantity         InvoiceDate  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1                  WHITE METAL LANTERN         6 2010-12-01 08:26:00
# 2       CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00
# 3  KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01 08:26:00
# 4       RED WOOLLY HOTTIE WHITE HEART.         6 2010-12-01 08:26:00
# 5         SET 7 BABUSHKA NESTING BOXES         2 2010-12-01 08:26:00
# 6    GLASS STAR FROSTED T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 7               HAND WARMER UNION JACK         6 2010-12-01 08:28:00
# 8            HAND WARMER RED POLKA DOT         6 2010-12-01 08:28:00
# 9        ASSORTED COLOUR BIRD ORNAMENT        32 2010-12-01 08:34:00
#
#    UnitPrice  CustomerID         Country  order_canceled  TotalPrice
# 0       2.55       17850  United Kingdom               0       15.30
# 1       3.39       17850  United Kingdom               0       20.34
# 2       2.75       17850  United Kingdom               0       22.00
# 3       3.39       17850  United Kingdom               0       20.34
# 4       3.39       17850  United Kingdom               0       20.34
# 5       7.65       17850  United Kingdom               0       15.30
# 6       4.25       17850  United Kingdom               0       25.50
# 7       1.85       17850  United Kingdom               0       11.10
# 8       1.85       17850  United Kingdom               0       11.10
# 9       1.69       13047  United Kingdom               0       54.08

# %% [markdown]
# ## 4.2. Convert to Customer based (Aggreegate DATA - RFM Concept)

# %% [markdown]
# #### The RFM model is based on three quantitative factors:
# ##### Recency: How recently a customer has made a purchase
# ##### Frequency: How often a customer makes a purchase
# ##### Monetary Value: How much money a customer spends on purchases

# %% [markdown]
# #### Full Article : https://www.investopedia.com/terms/r/rfm-recency-frequency-monetary-value.asp

# %% [markdown]
# ##### Let us check the distribution of the TotalSum column to understand customer spending.

# %%
df.TotalPrice.hist(bins=20)
# Out:
# <AxesSubplot:>

# %% [raw]
# df.TotalPrice.plot.box()

# %%
df[['TotalPrice']].describe()
# Out:
#           TotalPrice
# count  401604.000000
# mean       20.613638
# std       430.352218
# min   -168469.600000
# 25%         4.250000
# 50%        11.700000
# 75%        19.800000
# max    168469.600000

# %%
df[df['TotalPrice']> 19.800000].sort_values('TotalPrice',ascending=False)
# Out:
#        InvoiceNo StockCode  year_month  Month  Day  Hour  \
# 401131    581483     23843      201112     12    5     9
# 37511     541431     23166      201101      1    2    10
# 157405    556444     22502      201106      6    5    15
# 119907    551697      POST      201105      5    2    13
# 252000    567423     23243      201109      9    2    11
# ...          ...       ...         ...    ...  ...   ...
# 348174    576339     22591      201111     11    1    15
# 347937    576339     21035      201111     11    1    15
# 347910    576339     20682      201111     11    1    15
# 326061    574355     23403      201111     11    5    10
# 319647    573576     84347      201110     10    1    14
#
#                                 Description  Quantity         InvoiceDate  \
# 401131          PAPER CRAFT , LITTLE BIRDIE     80995 2011-12-09 09:15:00
# 37511        MEDIUM CERAMIC TOP STORAGE JAR     74215 2011-01-18 10:01:00
# 157405       PICNIC BASKET WICKER 60 PIECES        60 2011-06-10 15:28:00
# 119907                              POSTAGE         1 2011-05-03 13:46:00
# 252000  SET OF TEA COFFEE SUGAR TINS PANTRY      1412 2011-09-20 11:05:00
# ...                                     ...       ...                 ...
# 348174    CARDHOLDER GINGHAM CHRISTMAS TREE         3 2011-11-14 15:27:00
# 347937      SET/2 RED RETROSPOT TEA TOWELS          3 2011-11-14 15:27:00
# 347910     RED RETROSPOT CHILDRENS UMBRELLA         3 2011-11-14 15:27:00
# 326061        LETTER HOLDER HOME SWEET HOME         8 2011-11-04 10:48:00
# 319647  ROTATING SILVER ANGELS T-LIGHT HLDR         4 2011-10-31 14:09:00
#
#         UnitPrice  CustomerID         Country  order_canceled  TotalPrice
# 401131       2.08       16446  United Kingdom               0   168469.60
# 37511        1.04       12346  United Kingdom               0    77183.60
# 157405     649.50       15098  United Kingdom               0    38970.00
# 119907    8142.75       16029  United Kingdom               0     8142.75
# 252000       5.06       17450  United Kingdom               0     7144.72
# ...           ...         ...             ...             ...         ...
# 348174       6.63       14096  United Kingdom               0       19.89
# 347937       6.63       14096  United Kingdom               0       19.89
# 347910       6.63       14096  United Kingdom               0       19.89
# 326061       2.48       18102  United Kingdom               0       19.84
# 319647       4.96       14096  United Kingdom               0       19.84
#
# [89493 rows x 14 columns]

# %% [markdown]
# ##### Let check the max date and take data till a year behind the max date.

# %%
all_dates = (pd.to_datetime(df['InvoiceDate'])).apply(lambda x:x.date())

# %%
start_date = all_dates.max() - relativedelta(months=12, days=-1)
print('Start date: {}'.format(start_date))
print('End date: {}'.format(all_dates.max()))
# Out:
# Start date: 2010-12-10
# End date: 2011-12-09

# %%
data_rfm = df[df['InvoiceDate'] >= pd.to_datetime(start_date)]
data_rfm.reset_index(drop=True,inplace=True)
data_rfm.head()
# Out:
#   InvoiceNo StockCode  year_month  Month  Day  Hour  \
# 0    538172     21562      201012     12    5     9
# 1    538172     79321      201012     12    5     9
# 2    538172     22041      201012     12    5     9
# 3    538172    84558A      201012     12    5     9
# 4    538172     22952      201012     12    5     9
#
#                        Description  Quantity         InvoiceDate  UnitPrice  \
# 0            HAWAIIAN GRASS SKIRT         12 2010-12-10 09:33:00       1.25
# 1                    CHILLI LIGHTS         8 2010-12-10 09:33:00       4.95
# 2     RECORD FRAME 7" SINGLE SIZE         12 2010-12-10 09:33:00       2.55
# 3     3D DOG PICTURE PLAYING CARDS        12 2010-12-10 09:33:00       2.95
# 4  60 CAKE CASES VINTAGE CHRISTMAS        24 2010-12-10 09:33:00       0.55
#
#    CustomerID         Country  order_canceled  TotalPrice
# 0       15805  United Kingdom               0        15.0
# 1       15805  United Kingdom               0        39.6
# 2       15805  United Kingdom               0        30.6
# 3       15805  United Kingdom               0        35.4
# 4       15805  United Kingdom               0        13.2

# %%
snapshot_date = max(data_rfm.InvoiceDate) + dt.timedelta(days=1)
print('Snapshot date: {}'.format(snapshot_date.date()))
# Out:
# Snapshot date: 2011-12-10

# %%
# Aggregate data on a customer level
data = data_rfm.groupby(['CustomerID'],as_index=False).agg(Recency = ('InvoiceDate', lambda x: (snapshot_date - x.max()).days),
                                                           Frequency = ('InvoiceNo', 'count'),
                                                           MonetaryValue = ('TotalPrice', 'sum'),
                                                           AgeOnPlatform = ('InvoiceDate', lambda x: (snapshot_date - x.min()).days),
                                                           NumberOfCancel = ('order_canceled', 'sum')
                                                          )

# Check the first rows
data.head()
# Out:
#    CustomerID  Recency  Frequency  MonetaryValue  AgeOnPlatform  \
# 0       12346      326          2           0.00            326
# 1       12347        2        151        3598.21            317
# 2       12348       75         31        1797.24            358
# 3       12349       19         73        1757.55             19
# 4       12350      310         17         334.40            310
#
#    NumberOfCancel
# 0               1
# 1               0
# 2               0
# 3               0
# 4               0

# %%
data[data['NumberOfCancel']>1]
# Out:
#       CustomerID  Recency  Frequency  MonetaryValue  AgeOnPlatform  \
# 5          12352       36         95   1.545410e+03            297
# 12         12359        8        251   6.182980e+03            332
# 15         12362        3        274   5.154580e+03            296
# 30         12381        5         91   1.803960e+03            120
# 32         12384       29         30   5.661600e+02            122
# ...          ...      ...        ...            ...            ...
# 4277       18260      173        139   2.580150e+03            358
# 4284       18270       38         13   2.389500e+02            267
# 4285       18272        3        170   3.064780e+03            247
# 4287       18274       18         22   1.243450e-14             30
# 4288       18276       21         16   3.233600e+02             44
#
#       NumberOfCancel
# 5                 10
# 12                 6
# 15                 8
# 30                 4
# 32                 3
# ...              ...
# 4277               6
# 4284               2
# 4285               4
# 4287              11
# 4288               2
#
# [1049 rows x 6 columns]

# %%
data_rfm[data_rfm['order_canceled']>0]
# Out:
#        InvoiceNo StockCode  year_month  Month  Day  Hour  \
# 1050     C538314     22586      201012     12    5    13
# 1073     C538341     84380      201012     12    5    14
# 1074     C538341     22988      201012     12    5    14
# 1075     C538341     22988      201012     12    5    14
# 1076     C538341     22976      201012     12    5    14
# ...          ...       ...         ...    ...  ...   ...
# 386676   C581490     23144      201112     12    5     9
# 386760   C581499         M      201112     12    5    10
# 386927   C581568     21258      201112     12    5    11
# 386928   C581569     84978      201112     12    5    11
# 386929   C581569     20979      201112     12    5    11
#
#                               Description  Quantity         InvoiceDate  \
# 1050     FELTCRAFT HAIRBAND PINK AND BLUE       -47 2010-12-10 13:52:00
# 1073    SET OF 3 BUTTERFLY COOKIE CUTTERS        -1 2010-12-10 14:03:00
# 1074                    SOLDIERS EGG CUP        -36 2010-12-10 14:03:00
# 1075                    SOLDIERS EGG CUP        -12 2010-12-10 14:03:00
# 1076     CIRCUS PARADE CHILDRENS EGG CUP        -12 2010-12-10 14:03:00
# ...                                   ...       ...                 ...
# 386676    ZINC T-LIGHT HOLDER STARS SMALL       -11 2011-12-09 09:57:00
# 386760                             Manual        -1 2011-12-09 10:28:00
# 386927         VICTORIAN SEWING BOX LARGE        -5 2011-12-09 11:57:00
# 386928   HANGING HEART JAR T-LIGHT HOLDER        -1 2011-12-09 11:58:00
# 386929      36 PENCILS TUBE RED RETROSPOT        -5 2011-12-09 11:58:00
#
#         UnitPrice  CustomerID         Country  order_canceled  TotalPrice
# 1050         0.85       15514  United Kingdom               1      -39.95
# 1073         1.25       15514  United Kingdom               1       -1.25
# 1074         1.25       15514  United Kingdom               1      -45.00
# 1075         1.25       15514  United Kingdom               1      -15.00
# 1076         1.25       15514  United Kingdom               1      -15.00
# ...           ...         ...             ...             ...         ...
# 386676       0.83       14397  United Kingdom               1       -9.13
# 386760     224.69       15498  United Kingdom               1     -224.69
# 386927      10.95       15311  United Kingdom               1      -54.75
# 386928       1.25       17315  United Kingdom               1       -1.25
# 386929       1.25       17315  United Kingdom               1       -6.25
#
# [8574 rows x 14 columns]

# %%
# # Aggregate data on a customer level
# data = data_rfm.groupby(['CustomerID'],as_index=False).agg({'InvoiceDate': lambda x: (snapshot_date - x.max()).days,
#                                              'InvoiceNo': 'count',
#                                              'TotalPrice': 'sum'
#                                              }).rename(columns = {'InvoiceDate': 'Recency',
#                                                                                    'InvoiceNo': 'Frequency',
#                                                                                    'TotalPrice': 'MonetaryValue',
#                                                                                     })

# # Check the first rows
# data.head()

# %%
data_rfm[data_rfm['CustomerID'] == 12346]
# Out:
#       InvoiceNo StockCode  year_month  Month  Day  Hour  \
# 23028    541431     23166      201101      1    2    10
# 23033   C541433     23166      201101      1    2    10
#
#                           Description  Quantity         InvoiceDate  \
# 23028  MEDIUM CERAMIC TOP STORAGE JAR     74215 2011-01-18 10:01:00
# 23033  MEDIUM CERAMIC TOP STORAGE JAR    -74215 2011-01-18 10:17:00
#
#        UnitPrice  CustomerID         Country  order_canceled  TotalPrice
# 23028       1.04       12346  United Kingdom               0     77183.6
# 23033       1.04       12346  United Kingdom               1    -77183.6

# %%
r_labels = range(4, 0, -1)
r_quartiles = pd.qcut(data['Recency'], 4, labels = r_labels)
data = data.assign(R = r_quartiles.values)

f_labels = range(1,5)
m_labels = range(1,5)
f_quartiles = pd.qcut(data['Frequency'], 4, labels = f_labels)
m_quartiles = pd.qcut(data['MonetaryValue'], 4, labels = m_labels)
data = data.assign(F = f_quartiles.values)
data = data.assign(M = m_quartiles.values)
data.head()
# Out:
#    CustomerID  Recency  Frequency  MonetaryValue  AgeOnPlatform  \
# 0       12346      326          2           0.00            326
# 1       12347        2        151        3598.21            317
# 2       12348       75         31        1797.24            358
# 3       12349       19         73        1757.55             19
# 4       12350      310         17         334.40            310
#
#    NumberOfCancel  R  F  M
# 0               1  1  1  1
# 1               0  4  4  4
# 2               0  2  2  4
# 3               0  3  3  4
# 4               0  1  1  2

# %%
def join_rfm(x):
    return str(x['R']) + str(x['F']) + str(x['M'])

data['RFM_Segment'] = data.apply(join_rfm, axis=1)
data['RFM_Score'] = data[['R','F','M']].sum(axis=1)
data.head()
# Out:
#    CustomerID  Recency  Frequency  MonetaryValue  AgeOnPlatform  \
# 0       12346      326          2           0.00            326
# 1       12347        2        151        3598.21            317
# 2       12348       75         31        1797.24            358
# 3       12349       19         73        1757.55             19
# 4       12350      310         17         334.40            310
#
#    NumberOfCancel  R  F  M RFM_Segment  RFM_Score
# 0               1  1  1  1   1.01.01.0          3
# 1               0  4  4  4   4.04.04.0         12
# 2               0  2  2  4   2.02.04.0          8
# 3               0  3  3  4   3.03.04.0         10
# 4               0  1  1  2   1.01.02.0          4

# %% [markdown]
# ##### RFM Score distribution and their groups.

# %%
data.groupby('RFM_Score').agg({'Recency': 'mean',
                                   'Frequency': 'mean',
                                   'MonetaryValue': ['mean', 'count'] }).round(1)
# Out:
#           Recency Frequency MonetaryValue
#              mean      mean          mean count
# RFM_Score
# 3           247.7       7.9         106.0   389
# 4           163.2      13.8         220.3   377
# 5           146.7      20.5         348.3   503
# 6            85.8      27.5         482.0   459
# 7            80.9      39.6         718.8   447
# 8            56.3      53.4         953.5   453
# 9            44.3      76.9        1338.7   410
# 10           30.3     111.8        1808.0   436
# 11           19.9     188.2        3856.7   357
# 12            6.7     358.0        8574.5   465

# %%
def create_segment(df):
    if df['RFM_Score'] >= 9:
        return 'Top'
    elif (df['RFM_Score'] >= 5) and (df['RFM_Score'] < 9):
        return 'Middle'
    else:
        return 'Low'
    
data['General_Segment'] = data.apply(create_segment, axis=1)
data.groupby('General_Segment').agg({'Recency': 'mean',
                                         'Frequency': 'mean',
                                         'MonetaryValue': ['mean', 'count']}).round(1)
# Out:
#                 Recency Frequency MonetaryValue
#                    mean      mean          mean count
# General_Segment
# Low               206.1      10.8         162.2   766
# Middle             93.9      34.8         617.4  1862
# Top                24.9     188.2        4017.5  1668

# %%
df['CustomerID'][df['TotalPrice']==df['TotalPrice'].max()]
# Out:
# 401131    16446
# Name: CustomerID, dtype: int32

# %%
df[df['TotalPrice'] == df['TotalPrice'].max()]
# Out:
#        InvoiceNo StockCode  year_month  Month  Day  Hour  \
# 401131    581483     23843      201112     12    5     9
#
#                         Description  Quantity         InvoiceDate  UnitPrice  \
# 401131  PAPER CRAFT , LITTLE BIRDIE     80995 2011-12-09 09:15:00       2.08
#
#         CustomerID         Country  order_canceled  TotalPrice
# 401131       16446  United Kingdom               0    168469.6

# %% [markdown]
# # 4.EDA analysis

# %% [markdown]
# ### 4.1. Customer

# %% [markdown]
# #### Which customer has spent the most and less on our platform?

# %%
# Show top 10 customers, max and min amounts paid   
res_df = df.groupby(['CustomerID']).sum()
res_df.sort_values('TotalPrice',ascending=False,inplace=True)
final_df = res_df[(res_df['Quantity'] > 0) & (res_df['TotalPrice'] > 0)]

print('customer Id {} who paid the maximum amount {}'.format(int(final_df.index.values[final_df['TotalPrice']==final_df['TotalPrice'].max()]),final_df['TotalPrice'].max()))
print('customer Id {} who paid the minimum amount {}'.format(int(final_df.index.values[final_df['TotalPrice']==final_df['TotalPrice'].min()]),final_df['TotalPrice'].min()))

final_df[['TotalPrice','Quantity']].head(10)
# Out:
# customer Id 14646 who paid the maximum amount 279489.0199999999
# customer Id 16446 who paid the minimum amount 2.8999999999941792
#             TotalPrice  Quantity
# CustomerID
# 14646        279489.02    196719
# 18102        256438.49     64122
# 17450        187322.17     69009
# 14911        132458.73     77155
# 12415        123725.45     77242
# 14156        113214.59     56908
# 17511         88125.38     63012
# 16684         65892.08     49390
# 13694         62690.54     61899
# 15311         59284.19     37673

# %%
top10 = final_df[['TotalPrice']][:10]

# %%
top10.sort_values(by=['TotalPrice'],ascending=False,inplace=True)

# %%
plt.figure(figsize=(15,10))
# X = final_df.index.values[:10]
# Y = final_df['TotalPrice'][:10]
splot=sns.barplot(x = top10.index, y = "TotalPrice", data=top10)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.2f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')
plt.xlabel("CustomerID", size=14)
plt.ylabel("Total spent amount", size=14)
# Out:
# Text(0, 0.5, 'Total spent amount')

# %% [markdown]
# #### Which customer has the most transaction?

# %%
# Show top 10 customers, max and min amounts paid   
res_df = df.groupby(['CustomerID']).sum()
res_df.sort_values('order_canceled',ascending=False,inplace=True)
second_df_a = res_df[res_df['order_canceled'] > 0]

# print('customer Id {} who paid the maximum amount {}'.format(int(final_df.index.values[final_df['TotalPrice']==final_df['TotalPrice'].max()]),final_df['TotalPrice'].max()))
# print('customer Id {} who paid the minimum amount {}'.format(int(final_df.index.values[final_df['TotalPrice']==final_df['TotalPrice'].min()]),final_df['TotalPrice'].min()))

# final_df[['TotalPrice','Quantity']].head(10)

# %%
top10_seconda = second_df_a[['order_canceled']][:10]
top10_seconda
# Out:
#             order_canceled
# CustomerID
# 14911                  226
# 17841                  136
# 17511                  113
# 15311                  112
# 12607                  101
# 14410                   92
# 13798                   89
# 14606                   82
# 13113                   79
# 12471                   71

# %%
second_df_b = data_rfm.groupby(['CustomerID'],as_index=False).agg(
                                                           NumberOfTransaction = ('InvoiceNo', 'count'))
second_df_b.sort_values('NumberOfTransaction', ascending=False,inplace=True)

# %%
top10_secondb = second_df_b[:10]
top10_secondb.sort_values(by=['NumberOfTransaction'],ascending=False,inplace=True)
top10_secondb.reset_index(drop=True,inplace=True)

# %%
top10_secondb
# Out:
#    CustomerID  NumberOfTransaction
# 0       17841                 7623
# 1       14911                 5737
# 2       14096                 5128
# 3       12748                 4100
# 4       14606                 2637
# 5       15311                 2370
# 6       14646                 2085
# 7       13089                 1812
# 8       13263                 1667
# 9       14298                 1640

# %%
plt.figure(figsize=(15,10))
# X = final_df.index.values[:10]
# Y = final_df['TotalPrice'][:10]
splot=sns.barplot(x = "CustomerID", y = "NumberOfTransaction", data=top10_secondb)
for p in splot.patches:
    splot.annotate(format(p.get_height()), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')
plt.xlabel("Customer ID", size=14)
plt.ylabel("Number of transaction", size=14)
# Out:
# Text(0, 0.5, 'Number of transaction')

# %% [markdown]
# ### 4.2. Product

# %% [markdown]
# #### Which product that customer has ordered the most?

# %%
top_products = df['Description'].value_counts()[:10]
plt.figure(figsize=(8,6))
sns.set_context("paper", font_scale=1.5)
sns.barplot(y = top_products.index,
            x = top_products.values, 
           palette='PuBuGn_d')
plt.title("Top selling products")
plt.show()

# %% [markdown]
# ### 4.3. Country

# %% [markdown]
# #### How many orders for each country?

# %%
group_country_orders = df.groupby('Country')['InvoiceNo'].count().sort_values()
# del group_country_orders['United Kingdom']

# plot number of unique customers in each country (with UK)
plt.subplots(figsize=(15,8))
group_country_orders.plot(kind='barh', fontsize=12)
plt.xlabel('Number of Orders', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Number of Orders for different Countries', fontsize=12)
plt.show()

# %%
group_country_orders = df.groupby('Country')['InvoiceNo'].count().sort_values()
del group_country_orders['United Kingdom']

# plot number of unique customers in each country (with UK)
plt.subplots(figsize=(15,8))
group_country_orders.plot(kind='barh', fontsize=12)
plt.xlabel('Number of Orders', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Number of Orders for different Countries', fontsize=12)
plt.show()

# %% [markdown]
# #### How much money spent by each country?¶

# %%
group_country_amount_spent = df.groupby('Country')['TotalPrice'].sum().sort_values()
# del group_country_orders['United Kingdom']

# plot total money spent by each country (with UK)
plt.subplots(figsize=(15,8))
group_country_amount_spent.plot(kind='barh', fontsize=12)
plt.xlabel('Money Spent (Dollar)', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Money Spent by different Countries', fontsize=12)
plt.show()

# %%
group_country_amount_spent = df.groupby('Country')['TotalPrice'].sum().sort_values()
del group_country_amount_spent['United Kingdom']

# plot total money spent by each country (with UK)
plt.subplots(figsize=(15,8))
group_country_amount_spent.plot(kind='barh', fontsize=12)
plt.xlabel('Money Spent (Dollar)', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Money Spent by different Countries', fontsize=12)
plt.show()

# %% [markdown]
# ### 4.4. Sales Performance

# %% [markdown]
# #### How many orders (per month)?

# %%
ax = df.groupby('InvoiceNo')['year_month'].unique().value_counts().sort_index().plot(kind='bar',figsize=(15,6))
ax.set_xlabel('Month',fontsize=15)
ax.set_ylabel('Number of Orders',fontsize=15)
ax.set_title('Number of orders for different Months (1st Dec 2010 - 9th Dec 2011)',fontsize=15)
ax.set_xticklabels(('Dec_10','Jan_11','Feb_11','Mar_11','Apr_11','May_11','Jun_11','July_11','Aug_11','Sep_11','Oct_11','Nov_11','Dec_11'), rotation='horizontal', fontsize=13)
plt.show()

# %% [markdown]
# #### How many orders (per day)?

# %%
df.groupby('InvoiceNo')['Day'].unique().value_counts().sort_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'numpy.ndarray'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1709, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'numpy.ndarray'
# [1]    3512
# [2]    3892
# [3]    4110
# [4]    4978
# [5]    3356
# [7]    2342
# Name: Day, dtype: int64

# %%
ax = df.groupby('InvoiceNo')['Day'].unique().value_counts().sort_index().plot(kind='bar',figsize=(15,6))
ax.set_xlabel('Day',fontsize=15)
ax.set_ylabel('Number of Orders',fontsize=15)
ax.set_title('Number of orders for different Days',fontsize=15)
ax.set_xticklabels(('Mon','Tue','Wed','Thur','Fri','Sun'), rotation='horizontal', fontsize=15)
plt.show()

# %% [markdown]
# #### How many orders (per hour)?

# %%
df.groupby('InvoiceNo')['Hour'].unique().value_counts().iloc[:-1].sort_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'numpy.ndarray'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1709, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'numpy.ndarray'
# [6]       22
# [7]       31
# [8]      608
# [9]     1622
# [10]    2613
# [11]    2769
# [12]    3596
# [13]    3043
# [14]    2645
# [15]    2405
# [16]    1491
# [17]     842
# [18]     257
# [19]     217
# [20]      28
# Name: Hour, dtype: int64

# %%
ax = df.groupby('InvoiceNo')['Hour'].unique().value_counts().iloc[:-1].sort_index().plot(kind='bar',figsize=(15,6))
ax.set_xlabel('Hour',fontsize=15)
ax.set_ylabel('Number of Orders',fontsize=15)
ax.set_title('Number of orders for different Hours',fontsize=15)
ax.set_xticklabels(range(6,21), rotation='horizontal', fontsize=15)
plt.show()

# %%
df.UnitPrice.describe()
# Out:
# count    401604.000000
# mean          3.474064
# std          69.764035
# min           0.000000
# 25%           1.250000
# 50%           1.950000
# 75%           3.750000
# max       38970.000000
# Name: UnitPrice, dtype: float64

# %% [markdown]
# ##### We see that there are unit price = 0 (FREE items)

# %%
# check the distribution of unit price
plt.subplots(figsize=(12,6))
sns.boxplot(df.UnitPrice)
plt.show()

# %%
df_free = df[df.UnitPrice == 0]

# %%
df[df.UnitPrice > 35000]
# Out:
#        InvoiceNo StockCode  year_month  Month  Day  Hour Description  \
# 157406   C556445         M      201106      6    5    15      Manual
#
#         Quantity         InvoiceDate  UnitPrice  CustomerID         Country  \
# 157406        -1 2011-06-10 15:31:00    38970.0       15098  United Kingdom
#
#         order_canceled  TotalPrice
# 157406               1    -38970.0

# %%
df_free.head()
# Out:
#       InvoiceNo StockCode  year_month  Month  Day  Hour  \
# 6842     537197     22841      201012     12    7    14
# 22619    539263     22580      201012     12    4    14
# 25551    539722     22423      201012     12    2    13
# 29374    540372     22090      201101      1    4    16
# 29376    540372     22553      201101      1    4    16
#
#                         Description  Quantity         InvoiceDate  UnitPrice  \
# 6842   ROUND CAKE TIN VINTAGE GREEN         1 2010-12-05 14:02:00        0.0
# 22619  ADVENT CALENDAR GINGHAM SACK         4 2010-12-16 14:36:00        0.0
# 25551      REGENCY CAKESTAND 3 TIER        10 2010-12-21 13:45:00        0.0
# 29374       PAPER BUNTING RETROSPOT        24 2011-01-06 16:41:00        0.0
# 29376        PLASTERS IN TIN SKULLS        24 2011-01-06 16:41:00        0.0
#
#        CustomerID         Country  order_canceled  TotalPrice
# 6842        12647         Germany               0         0.0
# 22619       16560  United Kingdom               0         0.0
# 25551       14911            EIRE               0         0.0
# 29374       13081  United Kingdom               0         0.0
# 29376       13081  United Kingdom               0         0.0

# %%
df_free.year_month.value_counts().sort_index()
# Out:
# 201012     3
# 201101     3
# 201102     1
# 201103     2
# 201104     2
# 201105     2
# 201107     2
# 201108     6
# 201109     2
# 201110     3
# 201111    14
# Name: year_month, dtype: int64

# %%
ax = df_free.year_month.value_counts().sort_index().plot(kind='bar',figsize=(12,6))
ax.set_xlabel('Month',fontsize=15)
ax.set_ylabel('Frequency',fontsize=15)
ax.set_title('Frequency for different Months (Dec 2010 - Dec 2011)',fontsize=15)
ax.set_xticklabels(('Dec_10','Jan_11','Feb_11','Mar_11','Apr_11','May_11','July_11','Aug_11','Sep_11','Oct_11','Nov_11'), rotation='horizontal', fontsize=13)
plt.show()

# %% [markdown]
# ##### Not clear why there are FREE items given to certain customers

# %% [markdown]
# ###### - On average, the company gave out 2-4 times FREE items to customers each month (Except in June 2011)

# %% [markdown]
# ##### Results obtained from Exploratory Data Analysis (EDA)
# 1. The customer with the highest number of orders comes from the United Kingdom (UK)
# 2. The customer with the highest money spent on purchases comes from Netherlandss
# 3. The company receives the highest number of orders from customers in the UK (since it is a UK-based company). Therefore, the TOP 5 countries (including UK) that place the highest number of orders are as below:
#     -United Kingdom
#     -Germany
#     -France
#     -Ireland (EIRE)
#     -Spain
# 4. As the company receives the highest number of orders from customers in the UK (since it is a UK-based company), customers in the UK spend the most on their purchases. Therefore, the TOP 5 countries (including UK) that spend the most money on   purchases are as below:
#     -United Kingdom
#     -Netherlands
#     -Ireland (EIRE)
#     -Germany
#     -France
# 5. November 2011 has the highest sales
#     -The month with the lowest sales is undetermined as the dataset consists of transactions until 9th December 2011 in December
# 6. There are no transactions on Saturday between 1st Dec 2010 - 9th Dec 2011
# 7. The number of orders received by the company tends to increases from Monday to Thursday and decrese afterward
# 8. The company receives the highest number of orders at 12:00pm
#     -Possibly most customers made purchases during lunch hour between 12:00pm - 2:00pm
# 9. The company tends to give out FREE items for purchases occasionally each month (Except June 2011)
#     -However, it is not clear what factors contribute to giving out the FREE items to the particular customers

# %% [markdown]
# # 5. Data Preprocessing

# %% [markdown]
# #### prepare the data for Kmeans clustering on RFM Score data

# %%
# Checking the distribution of Recency, Frequency and MonetaryValue variables.
plt.figure(figsize=(12,10))

# Plot distribution of var1
plt.subplot(3, 1, 1); sns.distplot(data['Recency'])

# Plot distribution of var2
plt.subplot(3, 1, 2); sns.distplot(data['Frequency'])

# Plot distribution of var3
plt.subplot(3, 1, 3); sns.distplot(data['MonetaryValue'])
# Out:
# <AxesSubplot:xlabel='MonetaryValue', ylabel='Density'>

# %%
plt.boxplot(data['Recency'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e91e601d60>,
#   <matplotlib.lines.Line2D at 0x1e91e601e20>],
#  'caps': [<matplotlib.lines.Line2D at 0x1e91e601ca0>,
#   <matplotlib.lines.Line2D at 0x1e91e601c10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1e91c21cf10>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e91e601970>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e91c29dc10>],
#  'means': []}

# %%
# removing (statistical) outliers
Q1 = data.MonetaryValue.quantile(0.05)
Q3 = data.MonetaryValue.quantile(0.95)
IQR = Q3 - Q1
data = data[(data.MonetaryValue >= Q1 - 1.5*IQR) & (data.MonetaryValue <= Q3 + 1.5*IQR)]

# outlier treatment for recency
Q1 = data.Recency.quantile(0.05)
Q3 = data.Recency.quantile(0.95)
IQR = Q3 - Q1
data = data[(data.Recency >= Q1 - 1.5*IQR) & (data.Recency <= Q3 + 1.5*IQR)]

# outlier treatment for frequency
Q1 = data.Frequency.quantile(0.05)
Q3 = data.Frequency.quantile(0.95)
IQR = Q3 - Q1
data = data[(data.Frequency >= Q1 - 1.5*IQR) & (data.Frequency <= Q3 + 1.5*IQR)]

# %% [markdown]
# ##### Use log transformation to unskew the data

# %%
# Checking for constant mean and variance.
data[['Recency','Frequency','MonetaryValue']].describe()
# Out:
#            Recency    Frequency  MonetaryValue
# count  4167.000000  4167.000000    4167.000000
# mean     87.153108    75.945524    1267.153421
# std      93.540234    96.815895    1722.977868
# min       1.000000     1.000000       2.900000
# 25%      17.000000    17.000000     293.275000
# 50%      50.000000    40.000000     636.140000
# 75%     133.000000    95.000000    1515.815000
# max     365.000000   712.000000   13309.040000

# %%
data[data['MonetaryValue'] < 0]
# Out:
# Empty DataFrame
# Columns: [CustomerID, Recency, Frequency, MonetaryValue, AgeOnPlatform, NumberOfCancel, R, F, M, RFM_Segment, RFM_Score, General_Segment]
# Index: []

# %%
# data = data[data['MonetaryValue'] > 0]
# data.reset_index(drop=True,inplace=True)

# %%
data[data['MonetaryValue'] > 0].tail(10)
# Out:
#       CustomerID  Recency  Frequency  MonetaryValue  AgeOnPlatform  \
# 4232       18270       38         13         238.95            267
# 4233       18272        3        170        3064.78            247
# 4234       18273        2          3         204.00            258
# 4235       18276       21         16         323.36             44
# 4236       18277       58          9          97.63            319
# 4237       18278       74          9         173.90             74
# 4238       18280      278         10         180.60            278
# 4239       18281      181          7          80.82            181
# 4240       18282        8         13         176.60            126
# 4242       18287       43         70        1837.28            202
#
#       NumberOfCancel  R  F  M RFM_Segment  RFM_Score General_Segment
# 4232               2  3  1  1   3.01.01.0          5          Middle
# 4233               4  4  4  4   4.04.04.0         12             Top
# 4234               0  4  1  1   4.01.01.0          6          Middle
# 4235               2  3  1  2   3.01.02.0          6          Middle
# 4236               1  2  1  1   2.01.01.0          4             Low
# 4237               0  2  1  1   2.01.01.0          4             Low
# 4238               0  1  1  1   1.01.01.0          3             Low
# 4239               0  1  1  1   1.01.01.0          3             Low
# 4240               1  4  1  1   4.01.01.0          6          Middle
# 4242               0  3  3  4   3.03.04.0         10             Top

# %%
# data = data.drop([4239, 1031, 752, 207, 165])
# data.reset_index(drop=True,inplace=True)

# %%
raw_data = data[['Recency','Frequency','MonetaryValue']]

# %%
raw_data
# Out:
#       Recency  Frequency  MonetaryValue
# 0           2        151        3598.21
# 1          75         31        1797.24
# 2          19         73        1757.55
# 3         310         17         334.40
# 4          36         95        1545.41
# ...       ...        ...            ...
# 4237       74          9         173.90
# 4238      278         10         180.60
# 4239      181          7          80.82
# 4240        8         13         176.60
# 4242       43         70        1837.28
#
# [4167 rows x 3 columns]

# %%
# Unskew the data
data_log = np.log(raw_data)

# Initialize a standard scaler and fit it
scaler = StandardScaler()
scaler.fit(data_log)

# Scale data
data_normalized = scaler.transform(data_log)

# Create a pandas DataFrame
data_norm = pd.DataFrame(data=data_log, index=raw_data.index, columns=raw_data.columns)

# %%
data_normalized
# Out:
# array([[-2.13647908,  1.08907635,  1.4645731 ],
#        [ 0.42158067, -0.17196108,  0.86557776],
#        [-0.54751738,  0.51018923,  0.84630855],
#        ...,
#        [ 1.04339674, -1.35716262, -1.81087782],
#        [-1.15803255, -0.86411945, -1.13639935],
#        [ 0.02895261,  0.4767662 ,  0.88459043]])

# %%
data_log.tail(10)
# Out:
#        Recency  Frequency  MonetaryValue
# 4232  3.637586   2.564949       5.476254
# 4233  1.098612   5.135798       8.027731
# 4234  0.693147   1.098612       5.318120
# 4235  3.044522   2.772589       5.778766
# 4236  4.060443   2.197225       4.581185
# 4237  4.304065   2.197225       5.158480
# 4238  5.627621   2.302585       5.196285
# 4239  5.198497   1.945910       4.392224
# 4240  2.079442   2.564949       5.173887
# 4242  3.761200   4.248495       7.516041

# %%
data_norm[data_norm['MonetaryValue'] < 0]
# Out:
# Empty DataFrame
# Columns: [Recency, Frequency, MonetaryValue]
# Index: []

# %%
data_norm
# Out:
#        Recency  Frequency  MonetaryValue
# 0     0.693147   5.017280       8.188192
# 1     4.317488   3.433987       7.494007
# 2     2.944439   4.290459       7.471676
# 3     5.736572   2.833213       5.812338
# 4     3.583519   4.553877       7.343045
# ...        ...        ...            ...
# 4237  4.304065   2.197225       5.158480
# 4238  5.627621   2.302585       5.196285
# 4239  5.198497   1.945910       4.392224
# 4240  2.079442   2.564949       5.173887
# 4242  3.761200   4.248495       7.516041
#
# [4167 rows x 3 columns]

# %%
plt.figure(figsize=(12,10))

# Plot recency distribution
plt.subplot(3, 1, 1); sns.distplot(data_norm['Recency'])

# Plot frequency distribution
plt.subplot(3, 1, 2); sns.distplot(data_norm['Frequency'])

# Plot monetary value distribution
plt.subplot(3, 1, 3); sns.distplot(data_norm['MonetaryValue'])


# Show the plot
plt.show()

# %% [markdown]
# ##### Use elbow method to identify number of K for K-mean

# %%
sse = {}

# Fit KMeans and calculate SSE for each k
for k in range(1, 21):
  
    # Initialize KMeans with k clusters
    kmeans = KMeans(n_clusters=k, random_state=1)
    
    # Fit KMeans on the normalized dataset
    kmeans.fit(data_norm)
    
    # Assign sum of squared distances to k element of dictionary
    sse[k] = kmeans.inertia_

# %%
plt.figure(figsize=(12,8))

plt.title('The Elbow Method')
plt.xlabel('k'); 
plt.ylabel('Sum of squared errors')
sns.pointplot(x=list(sse.keys()), y=list(sse.values()))
plt.show()

# %%
# silhouette analysis
range_n_clusters = [2, 3, 4, 5, 6, 7, 8]

for num_clusters in range_n_clusters:
    
    # intialise kmeans
    kmeans = KMeans(n_clusters=num_clusters)
    kmeans.fit(data_norm)
    
    cluster_labels = kmeans.labels_
    
    # silhouette score
    silhouette_avg = silhouette_score(data_norm, cluster_labels)
    print("For n_clusters={0}, the silhouette score is {1}".format(num_clusters, silhouette_avg))
# Out:
# For n_clusters=2, the silhouette score is 0.3905741470903004
# For n_clusters=3, the silhouette score is 0.29926097011726316
# For n_clusters=4, the silhouette score is 0.3122135051355028
# For n_clusters=5, the silhouette score is 0.2863565378648299
# For n_clusters=6, the silhouette score is 0.28079373324813356
# For n_clusters=7, the silhouette score is 0.2762602677680662
# For n_clusters=8, the silhouette score is 0.2688786766473911

# %%
kmeans = KMeans(n_clusters=4, random_state=1)

# Compute k-means clustering on pre-processed data
kmeans.fit(data_norm)

# Extract cluster labels from labels_ attribute
cluster_labels = kmeans.labels_

# %%
# Create a cluster label column in the original DataFrame
data_norm_k4 = data_norm.assign(Cluster = cluster_labels)
# data_k4 = raw_data.assign(Cluster = cluster_labels)

# %%
data_norm_k4.index = data['CustomerID'].astype(int)

# %%
data_norm_k4.head()
# Out:
#              Recency  Frequency  MonetaryValue  Cluster
# CustomerID
# 12347       0.693147   5.017280       8.188192        1
# 12348       4.317488   3.433987       7.494007        3
# 12349       2.944439   4.290459       7.471676        1
# 12350       5.736572   2.833213       5.812338        0
# 12352       3.583519   4.553877       7.343045        3

# %%
# Melt the data into along format so RFM values and metric names are stored in 1 column each
data_melt = pd.melt(data_norm_k4.reset_index(),
                    id_vars=['CustomerID', 'Cluster'],
                    value_vars=['Frequency', 'MonetaryValue','Recency'],
                    var_name='Attribute',
                    value_name='Value')

# %%
data_melt
# Out:
#        CustomerID  Cluster  Attribute     Value
# 0           12347        1  Frequency  5.017280
# 1           12348        3  Frequency  3.433987
# 2           12349        1  Frequency  4.290459
# 3           12350        0  Frequency  2.833213
# 4           12352        3  Frequency  4.553877
# ...           ...      ...        ...       ...
# 12496       18278        0    Recency  4.304065
# 12497       18280        0    Recency  5.627621
# 12498       18281        0    Recency  5.198497
# 12499       18282        2    Recency  2.079442
# 12500       18287        3    Recency  3.761200
#
# [12501 rows x 4 columns]

# %%
plt.title('Line plot of clustering')
sns.lineplot(x="Attribute", y="Value", hue='Cluster', data=data_melt)
# Out:
# <AxesSubplot:title={'center':'Line plot of clustering'}, xlabel='Attribute', ylabel='Value'>

# %% [markdown]
# ### Hierachicle Clustering

# %% [markdown]
# #### Single linkage use min distance of data point

# %%
# Single linkage: 

sing_mergings = linkage(data_norm, method="single", metric='euclidean')
dendrogram(sing_mergings)
plt.show()

# %% [markdown]
# #### Complete linkage use Max distance of data point

# %%
# Complete linkage

com_mergings = linkage(data_norm, method="complete", metric='euclidean')
dendrogram(com_mergings)
plt.show()

# %% [markdown]
# #### Average linkage use Average distance of data point

# %%
# Average linkage

mergings = linkage(data_norm, method="average", metric='euclidean')
dendrogram(mergings)
plt.show()

# %%
ward_mergings = linkage(data_norm, method="ward", metric='euclidean')
dendrogram(ward_mergings)
plt.show()

# %%
c, coph_dists = cophenet(ward_mergings, pdist(data_norm))

# %%
c
# Out:
# 0.5340131150185785

# %%
x, coph_dists = cophenet(com_mergings, pdist(data_norm))

# %%
x
# Out:
# 0.50567930189124

# %%
y, coph_dists = cophenet(sing_mergings, pdist(data_norm))
y
# Out:
# 0.47859847968505476

# %%
t, coph_dists = cophenet(mergings, pdist(data_norm))
t
# Out:
# 0.5980300107403907

# %%
# 3 clusters
hie_cluster_labels = cut_tree(ward_mergings, n_clusters=4).reshape(-1,)
hie_cluster_labels
# Out:
# array([0, 1, 0, ..., 2, 3, 1])

# %%
hie_data = data_norm.assign(Cluster = hie_cluster_labels)

# %%
hie_data.sample(10)
# Out:
#        Recency  Frequency  MonetaryValue  Cluster
# 1862  4.276666   2.639057       5.672705        3
# 1485  5.891644   3.091042       4.796204        2
# 2719  2.890372   4.488636       7.539144        0
# 678   2.890372   6.086775       8.048053        1
# 3037  1.098612   4.663439       7.158685        0
# 1443  5.602119   3.044522       5.555669        2
# 67    3.761200   2.397895       5.546739        3
# 4088  3.258097   6.129050       7.598094        1
# 2668  3.806662   4.189655       6.478126        3
# 4073  3.806662   3.761200       5.183692        3

# %%
hie_data[hie_data['Cluster'] > 0]
# Out:
#        Recency  Frequency  MonetaryValue  Cluster
# 1     4.317488   3.433987       7.494007        1
# 3     5.736572   2.833213       5.812338        2
# 4     3.583519   4.553877       7.343045        1
# 5     5.318120   1.386294       4.488636        2
# 6     5.446737   4.060443       6.984161        3
# ...        ...        ...            ...      ...
# 4237  4.304065   2.197225       5.158480        2
# 4238  5.627621   2.302585       5.196285        2
# 4239  5.198497   1.945910       4.392224        2
# 4240  2.079442   2.564949       5.173887        3
# 4242  3.761200   4.248495       7.516041        1
#
# [3575 rows x 4 columns]

# %%
hie_data.index = data['CustomerID'].astype(int)

# %%
data_norm_k4.head()
# Out:
#              Recency  Frequency  MonetaryValue  Cluster
# CustomerID
# 12347       0.693147   5.017280       8.188192        1
# 12348       4.317488   3.433987       7.494007        3
# 12349       2.944439   4.290459       7.471676        1
# 12350       5.736572   2.833213       5.812338        0
# 12352       3.583519   4.553877       7.343045        3

# %%
# Melt the data into along format so RFM values and metric names are stored in 1 column each
hie_data_melt = pd.melt(hie_data.reset_index(),
                    id_vars=['CustomerID', 'Cluster'],
                    value_vars=['Frequency', 'MonetaryValue','Recency'],
                    var_name='Attribute',
                    value_name='Value')

# %%
hie_data_melt
# Out:
#        CustomerID  Cluster  Attribute     Value
# 0           12347        0  Frequency  5.017280
# 1           12348        1  Frequency  3.433987
# 2           12349        0  Frequency  4.290459
# 3           12350        2  Frequency  2.833213
# 4           12352        1  Frequency  4.553877
# ...           ...      ...        ...       ...
# 12496       18278        2    Recency  4.304065
# 12497       18280        2    Recency  5.627621
# 12498       18281        2    Recency  5.198497
# 12499       18282        3    Recency  2.079442
# 12500       18287        1    Recency  3.761200
#
# [12501 rows x 4 columns]

# %%
plt.title('Line plot of clustering')
sns.lineplot(x="Attribute", y="Value", hue='Cluster', data=hie_data_melt)
# Out:
# <AxesSubplot:title={'center':'Line plot of clustering'}, xlabel='Attribute', ylabel='Value'>
